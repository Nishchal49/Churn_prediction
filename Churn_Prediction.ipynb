# %% [markdown]
# <h1> TELECOM CHURN PREDICTION</h1> <BR>
#
# Step 1: Importing  -Importing data and Standard Libraries <br>
# Step 2: Data Cleaning and Vissualization  - Looking data for missing values, remove unrequired data, managing data-types and Visualizing data with graphs and Charts and looking for outliers<br>
# Step 3: Preprocessing  - Standardizing and creating train test split <br>
# Step 4: Data Modeling & Prediction  -Create different sets of base and ensemble models and comparing their performance

# %% [markdown]
# # <b>Step 1: Importing </b>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sqlalchemy

# %%
data = pd.read_csv("/content/drive/MyDrive/TelcomCustomer-Churn.csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
data.describe()
# 3 neumeric features
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# # <b>Step 2: Data Cleaning and Analysing using Visualization </b>

# %%
data.isna().any()
# Out:
# customerID          False
# gender              False
# SeniorCitizen       False
# Partner             False
# Dependents          False
# tenure              False
# PhoneService        False
# MultipleLines       False
# InternetService     False
# OnlineSecurity      False
# OnlineBackup        False
# DeviceProtection    False
# TechSupport         False
# StreamingTV         False
# StreamingMovies     False
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %%
# Replacing objects with categorical data
for feature in data.columns:
    if data[feature].dtype == 'object':
        data[feature] = pd.Categorical(data[feature])# Replace strings with an integer
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   category
#  1   gender            7043 non-null   category
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   category
#  4   Dependents        7043 non-null   category
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   category
#  7   MultipleLines     7043 non-null   category
#  8   InternetService   7043 non-null   category
#  9   OnlineSecurity    7043 non-null   category
#  10  OnlineBackup      7043 non-null   category
#  11  DeviceProtection  7043 non-null   category
#  12  TechSupport       7043 non-null   category
#  13  StreamingTV       7043 non-null   category
#  14  StreamingMovies   7043 non-null   category
#  15  Contract          7043 non-null   category
#  16  PaperlessBilling  7043 non-null   category
#  17  PaymentMethod     7043 non-null   category
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   category
#  20  Churn             7043 non-null   category
# dtypes: category(18), float64(1), int64(2)
# memory usage: 927.0 KB

# %%
# Function for analysing categorical features
def hist_value(feature):
    pd.value_counts(feature).plot.bar()
    plt.title(feature.name +  ' class histogram')
    plt.xlabel('Class')
    plt.ylabel('Frequency')
    print(feature.value_counts())

# %%
hist_value(data['gender'])
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
hist_value(data['SeniorCitizen'])
# Out:
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %%
hist_value(data['Partner'])
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
hist_value(data['Dependents'])
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
hist_value(data['PhoneService'])
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
hist_value(data['MultipleLines'])
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
hist_value(data['InternetService'])
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
hist_value(data['OnlineSecurity'])
# Out:
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64

# %%
hist_value(data['DeviceProtection'])
# Out:
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64

# %%
hist_value(data['TechSupport'])
# Out:
# TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
hist_value(data['StreamingTV'])
# Out:
# StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64

# %%
hist_value(data['StreamingMovies'])
# Out:
# StreamingMovies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: count, dtype: int64

# %%
hist_value(data['Contract'])
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
hist_value(data['PaperlessBilling'])
# Out:
# PaperlessBilling
# Yes    4171
# No     2872
# Name: count, dtype: int64

# %%
hist_value(data['PaymentMethod'])
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
hist_value(data['Churn'])
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# <p style="color:DodgerBlue; "><b> Observations from above plots :  </b><br> <br>
#     <b>1: gender:- </b> Has almost equal ratios of Male and Female    <br>
#     <b>2: SeniorCitizen:-</b>  Number of Senior Citizens are way less than normal citizens    <br>
#     <b>3: Partner:-</b>  Has almost equal ratios of Partners and Non-Partners    <br>
#     <b>4: Dependents:-</b>  Number of Dependent users are way less than Non-Dependent Users    <br>
#     <b>5: PhoneService:-</b>  People who don't have Phone service are very few.    <br>
#     <b>6: MultipleLines:-</b>  MultipleLines are fewer than normal lines and customers who do not have PhoneService do not belong to this category.     <br>
#     <b>7: InternetService:-</b>  Fiber optic cable is most common interner service. There is large population which doesn't have internet service     <br>
#     <b>8: OnlineSecurity:- </b>  OnlineSecurity is not opted by maximum customers and customers who do not have InternetService do not belong to any category.    <br>
#     <b>9: DeviceProtection:- </b> DeviceProtection is not opted by maximum customers and customers who do not have InternetService do not belong to any category.   <br>
#    <b>10: TechSupport:- </b> TechSupport is not taken by maximum customers and customers who do not have InternetService do not belong to any category.     <br>
#     <b>11: StreamingTV:- </b> StreamingTV is equiprobable between customers who have InternetService and customers who do not have InternetService do not belong to any category.   <br>
#     <b>12: StreamingMovies:-</b>   StreamingMovies is equiprobable between customers who have InternetService and customers who do not have InternetService do not belong to any category.   <br>
#     <b>13: Contract:- </b>  Month t0 month contract is more likely opted by customers   <br>
#     <b>14: PaperlessBilling:-</b>  Most customers have opted for PaperlessBilling   <br>
#     <b>15: PaymentMethod:- </b> Electronic cheques is more preferred method of payment    <br>
#     <b>16: Churn:- </b> This is our target variable with majority class being a Non-Churner. We would require to balance these before moving to model building !!    <br> <br><br> <br>

# %% [markdown]
# <h3> Group Based Analysis </h3>

# %%
print('Male who Churned and Not Churned')
print(data.groupby(['gender']).get_group('Male').Churn.value_counts())
print('\n')
print('Female who Churned and Not Churned')
print(data.groupby(['gender']).get_group('Female').Churn.value_counts())
# Out:
# Male who Churned and Not Churned
# Churn
# No     2625
# Yes     930
# Name: count, dtype: int64
#
#
# Female who Churned and Not Churned
# Churn
# No     2549
# Yes     939
# Name: count, dtype: int64

# %%
print('Non-Senior Citizens who Churned and Not Churned')
print(data.groupby(['SeniorCitizen']).get_group(0).Churn.value_counts())
print('\n')
print('Senior Citizens who Churned and Not Churned')
print(data.groupby(['SeniorCitizen']).get_group(1).Churn.value_counts())
# Out:
# Non-Senior Citizens who Churned and Not Churned
# Churn
# No     4508
# Yes    1393
# Name: count, dtype: int64
#
#
# Senior Citizens who Churned and Not Churned
# Churn
# No     666
# Yes    476
# Name: count, dtype: int64

# %%
print('Partner who Churned and Not Churned')
print(data.groupby(['Partner']).get_group('Yes').Churn.value_counts())
print('\n')
print('Non-Partner who Churned and Not Churned')
print(data.groupby(['Partner']).get_group('No').Churn.value_counts())
# Out:
# Partner who Churned and Not Churned
# Churn
# No     2733
# Yes     669
# Name: count, dtype: int64
#
#
# Non-Partner who Churned and Not Churned
# Churn
# No     2441
# Yes    1200
# Name: count, dtype: int64

# %%
print('Dependents who Churned and Not Churned')
print(data.groupby(['Dependents']).get_group('Yes').Churn.value_counts())
print('\n')
print('Non-Dependents who Churned and Not Churned')
print(data.groupby(['Dependents']).get_group('No').Churn.value_counts())
# Out:
# Dependents who Churned and Not Churned
# Churn
# No     1784
# Yes     326
# Name: count, dtype: int64
#
#
# Non-Dependents who Churned and Not Churned
# Churn
# No     3390
# Yes    1543
# Name: count, dtype: int64

# %%
print('Customer with PhoneService who Churned and Not Churned')
print(data.groupby(['PhoneService']).get_group('Yes').Churn.value_counts())
print('\n')
print('Customer with No PhoneService who Churned and Not Churned')
print(data.groupby(['PhoneService']).get_group('No').Churn.value_counts())
# Out:
# Customer with PhoneService who Churned and Not Churned
# Churn
# No     4662
# Yes    1699
# Name: count, dtype: int64
#
#
# Customer with No PhoneService who Churned and Not Churned
# Churn
# No     512
# Yes    170
# Name: count, dtype: int64

# %%
print('Customer with MultipleLines who Churned and Not Churned')
print(data.groupby(['MultipleLines']).get_group('Yes').Churn.value_counts())
print('\n')
print('Customer with No MultipleLines who Churned and Not Churned')
print(data.groupby(['MultipleLines']).get_group('No').Churn.value_counts())
print('\n')
print('Customer with No PhoneService who Churned and Not Churned')
print(data.groupby(['MultipleLines']).get_group('No phone service').Churn.value_counts())
# Out:
# Customer with MultipleLines who Churned and Not Churned
# Churn
# No     2121
# Yes     850
# Name: count, dtype: int64
#
#
# Customer with No MultipleLines who Churned and Not Churned
# Churn
# No     2541
# Yes     849
# Name: count, dtype: int64
#
#
# Customer with No PhoneService who Churned and Not Churned
# Churn
# No     512
# Yes    170
# Name: count, dtype: int64

# %%
print('Customer with DSL InternetService who Churned and Not Churned')
print(data.groupby(['InternetService']).get_group('DSL').Churn.value_counts())
print('\n')
print('Customer with Fiber optic InternetService who Churned and Not Churned')
print(data.groupby(['InternetService']).get_group('Fiber optic').Churn.value_counts())
print('\n')
print('Customer with No InternetService who Churned and Not Churned')
print(data.groupby(['InternetService']).get_group('No').Churn.value_counts())
# Out:
# Customer with DSL InternetService who Churned and Not Churned
# Churn
# No     1962
# Yes     459
# Name: count, dtype: int64
#
#
# Customer with Fiber optic InternetService who Churned and Not Churned
# Churn
# No     1799
# Yes    1297
# Name: count, dtype: int64
#
#
# Customer with No InternetService who Churned and Not Churned
# Churn
# No     1413
# Yes     113
# Name: count, dtype: int64

# %%
print('Customer with OnlineSecurity who Churned and Not Churned')
print(data.groupby(['OnlineSecurity']).get_group('Yes').Churn.value_counts())
print('\n')
print('Customer with No OnlineSecurity who Churned and Not Churned')
print(data.groupby(['OnlineSecurity']).get_group('No').Churn.value_counts())
# Out:
# Customer with OnlineSecurity who Churned and Not Churned
# Churn
# No     1724
# Yes     295
# Name: count, dtype: int64
#
#
# Customer with No OnlineSecurity who Churned and Not Churned
# Churn
# No     2037
# Yes    1461
# Name: count, dtype: int64

# %%
print('Customer with DeviceProtection who Churned and Not Churned')
print(data.groupby(['DeviceProtection']).get_group('Yes').Churn.value_counts())
print('\n')
print('Customer with No DeviceProtection who Churned and Not Churned')
print(data.groupby(['DeviceProtection']).get_group('No').Churn.value_counts())
# Out:
# Customer with DeviceProtection who Churned and Not Churned
# Churn
# No     1877
# Yes     545
# Name: count, dtype: int64
#
#
# Customer with No DeviceProtection who Churned and Not Churned
# Churn
# No     1884
# Yes    1211
# Name: count, dtype: int64

# %%
print('Customer with TechSupport who Churned and Not Churned')
print(data.groupby(['TechSupport']).get_group('Yes').Churn.value_counts())
print('\n')
print('Customer with No TechSupport who Churned and Not Churned')
print(data.groupby(['TechSupport']).get_group('No').Churn.value_counts())
# Out:
# Customer with TechSupport who Churned and Not Churned
# Churn
# No     1734
# Yes     310
# Name: count, dtype: int64
#
#
# Customer with No TechSupport who Churned and Not Churned
# Churn
# No     2027
# Yes    1446
# Name: count, dtype: int64

# %%
print('Customer with StreamingTV Service who Churned and Not Churned')
print(data.groupby(['StreamingTV']).get_group('Yes').Churn.value_counts())
print('\n')
print('Customer with No StreamingTV Service who Churned and Not Churned')
print(data.groupby(['StreamingTV']).get_group('No').Churn.value_counts())
# Out:
# Customer with StreamingTV Service who Churned and Not Churned
# Churn
# No     1893
# Yes     814
# Name: count, dtype: int64
#
#
# Customer with No StreamingTV Service who Churned and Not Churned
# Churn
# No     1868
# Yes     942
# Name: count, dtype: int64

# %%
print('Customer with StreamingMovies Service who Churned and Not Churned')
print(data.groupby(['StreamingMovies']).get_group('Yes').Churn.value_counts())
print('\n')
print('Customer with No StreamingMovies who Churned and Not Churned')
print(data.groupby(['StreamingMovies']).get_group('No').Churn.value_counts())
# Out:
# Customer with StreamingMovies Service who Churned and Not Churned
# Churn
# No     1914
# Yes     818
# Name: count, dtype: int64
#
#
# Customer with No StreamingMovies who Churned and Not Churned
# Churn
# No     1847
# Yes     938
# Name: count, dtype: int64

# %%
print('Customer with Contract on Month-to-month basis who Churned and Not Churned')
print(data.groupby(['Contract']).get_group('Month-to-month').Churn.value_counts())
print('\n')
print('Customer with Contract of One year who Churned and Not Churned')
print(data.groupby(['Contract']).get_group('One year').Churn.value_counts())
print('\n')
print('Customer with Contract of Two year who Churned and Not Churned')
print(data.groupby(['Contract']).get_group('Two year').Churn.value_counts())
# Out:
# Customer with Contract on Month-to-month basis who Churned and Not Churned
# Churn
# No     2220
# Yes    1655
# Name: count, dtype: int64
#
#
# Customer with Contract of One year who Churned and Not Churned
# Churn
# No     1307
# Yes     166
# Name: count, dtype: int64
#
#
# Customer with Contract of Two year who Churned and Not Churned
# Churn
# No     1647
# Yes      48
# Name: count, dtype: int64

# %% [markdown]
# <h3> One Hot Encoding of our Categorical Variables </h3>

# %%
replaceStruct = {"Churn":     {"No": 0, "Yes": 1 }  }
oneHotCols = ["gender","SeniorCitizen","Partner","Dependents","PhoneService","MultipleLines"
            ,"InternetService","OnlineSecurity","OnlineBackup",
            "DeviceProtection","TechSupport","StreamingTV","StreamingMovies",
            "Contract","PaperlessBilling","PaymentMethod"]

# %%
replaced_data=data.replace(replaceStruct, inplace=True)
replaced_data=pd.get_dummies(data, columns=oneHotCols)
replaced_data.head()
# Out:
#    customerID  tenure  MonthlyCharges TotalCharges Churn  gender_Female  \
# 0  7590-VHVEG       1           29.85        29.85     0           True
# 1  5575-GNVDE      34           56.95       1889.5     0          False
# 2  3668-QPYBK       2           53.85       108.15     1          False
# 3  7795-CFOCW      45           42.30      1840.75     0          False
# 4  9237-HQITU       2           70.70       151.65     1           True
#
#    gender_Male  SeniorCitizen_0  SeniorCitizen_1  Partner_No  ...  \
# 0        False             True            False       False  ...
# 1         True             True            False        True  ...
# 2         True             True            False        True  ...
# 3         True             True            False        True  ...
# 4        False             True            False        True  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                False                     True              False
# 1                False                    False               True
# 2                False                     True              False
# 3                False                    False               True
# 4                False                     True              False
#
#    Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0              False                False                  True
# 1              False                 True                 False
# 2              False                False                  True
# 3              False                 True                 False
# 4              False                False                  True
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check
# 0                       False
# 1                        True
# 2                        True
# 3                       False
# 4                       False
#
# [5 rows x 48 columns]

# %%
replaced_data.columns
# Out:
# Index(['customerID', 'tenure', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'gender_Female', 'gender_Male', 'SeniorCitizen_0', 'SeniorCitizen_1',
#        'Partner_No', 'Partner_Yes', 'Dependents_No', 'Dependents_Yes',
#        'PhoneService_No', 'PhoneService_Yes', 'MultipleLines_No',
#        'MultipleLines_No phone service', 'MultipleLines_Yes',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'OnlineSecurity_No',
#        'OnlineSecurity_No internet service', 'OnlineSecurity_Yes',
#        'OnlineBackup_No', 'OnlineBackup_No internet service',
#        'OnlineBackup_Yes', 'DeviceProtection_No',
#        'DeviceProtection_No internet service', 'DeviceProtection_Yes',
#        'TechSupport_No', 'TechSupport_No internet service', 'TechSupport_Yes',
#        'StreamingTV_No', 'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No', 'StreamingMovies_No internet service',
#        'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaperlessBilling_No', 'PaperlessBilling_Yes',
#        'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
replaced_data.shape
# Out:
# (7043, 48)

# %%
feature_with_blank = []
for feature in replaced_data.columns:
    if any(replaced_data[feature] == ' '):

        feature_with_blank.append(feature)
print(feature_with_blank)
# Only TotalCharges has blank spaces, rest are fine
# Out:
# ['TotalCharges']

# %%
replaced_data[replaced_data.TotalCharges == ' '].index
# Out:
# Index([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], dtype='int64')

# %% [markdown]
# <p> We see that we have blank values for TotalCharges at above indices. We first replace it with Nan values and then proceed.

# %%
replaced_data.replace(' ', np.nan, inplace=True)
print(replaced_data[replaced_data.TotalCharges == ' '].index)
print(replaced_data.TotalCharges.isna().value_counts())
# Out:
# Index([], dtype='int64')
# TotalCharges
# False    7032
# True       11
# Name: count, dtype: int64

# %%
replaced_data.TotalCharges = pd.to_numeric(replaced_data.TotalCharges)
replaced_data.TotalCharges.dtype
# Out:
# dtype('float64')

# %%
plt2=sns.distplot(replaced_data[replaced_data.Churn==0][replaced_data.TotalCharges.name],color='green',label='Non-Churner')
sns.distplot(replaced_data[replaced_data.Churn==1][replaced_data.TotalCharges.name],color='red',label='Churner')
plt2.set_title('Distribution of '+ replaced_data.TotalCharges.name,fontdict={'fontsize':10})
plt2.set_xlabel(replaced_data.TotalCharges.name,fontdict={'fontsize':9})
plt2.set_ylabel('Count/Dist.',fontdict={'fontsize':9})
plt2.axes.legend(loc=0)
# Out:
# <ipython-input-54-74e831d5c5fa>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   plt2=sns.distplot(replaced_data[replaced_data.Churn==0][replaced_data.TotalCharges.name],color='green',label='Non-Churner')
# <ipython-input-54-74e831d5c5fa>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(replaced_data[replaced_data.Churn==1][replaced_data.TotalCharges.name],color='red',label='Churner')

# %%
median_df=replaced_data.groupby('Churn')['TotalCharges'].median()
median_df
# Out:
# Churn
# 0    1683.60
# 1     703.55
# Name: TotalCharges, dtype: float64

# %% [markdown]
# <p style="color:DodgerBlue; "> Customers who do not churn have TotalCharges median value as 1683.60 which is way
#     higher than people who churn. So update all missing values accordingly.
# </p><br> <br>

# %%
var_0=median_df.iloc[0]
var_1=median_df.iloc[1]
replaced_data.loc[(replaced_data['Churn'] == 0) & (replaced_data['TotalCharges'].isnull()), 'TotalCharges'] = var_0
replaced_data.loc[(replaced_data['Churn'] == 1) & (replaced_data['TotalCharges'].isnull()), 'TotalCharges'] = var_1
print(replaced_data.TotalCharges.isna().value_counts())
# Out:
# TotalCharges
# False    7043
# Name: count, dtype: int64

# %% [markdown]
# # <br>Step 3: Preprocessing <br>
#
# <p style="color:DodgerBlue; ">Balancing data for Churn Label first using SMOTE, then standardize
#     our data and finally move to model building part.
# </p><br> <br>

# %%
# Dropping customerID
replaced_data=replaced_data.drop('customerID',axis=1)
replaced_data.head()
# Out:
#    tenure  MonthlyCharges  TotalCharges Churn  gender_Female  gender_Male  \
# 0       1           29.85         29.85     0           True        False
# 1      34           56.95       1889.50     0          False         True
# 2       2           53.85        108.15     1          False         True
# 3      45           42.30       1840.75     0          False         True
# 4       2           70.70        151.65     1           True        False
#
#    SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  ...  \
# 0             True            False       False         True  ...
# 1             True            False        True        False  ...
# 2             True            False        True        False  ...
# 3             True            False        True        False  ...
# 4             True            False        True        False  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                False                     True              False
# 1                False                    False               True
# 2                False                     True              False
# 3                False                    False               True
# 4                False                     True              False
#
#    Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0              False                False                  True
# 1              False                 True                 False
# 2              False                False                  True
# 3              False                 True                 False
# 4              False                False                  True
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check
# 0                       False
# 1                        True
# 2                        True
# 3                       False
# 4                       False
#
# [5 rows x 47 columns]

# %%
# Seperating Churn
churn=replaced_data['Churn']
x=replaced_data.drop('Churn',axis=1)

# %%
# scatter plot of examples by class label
pd.value_counts(replaced_data['Churn']).plot.bar()
plt.title('Churn class histogram')
plt.xlabel('Churn')
plt.ylabel('Frequency')
replaced_data['Churn'].value_counts()
# Out:
# Churn
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
# Train and test splits
# Synthetic minority oversampling technique(SMOTE)
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
X_train, X_test, y_train, y_test = train_test_split(x, churn, test_size=0.2, random_state=0)

print("Number Observations in X_train dataset: ", X_train.shape)
print("Number Observations in y_train dataset: ", y_train.shape)
print("Number Observations in X_test dataset: ", X_test.shape)
print("Number Observations in y_test dataset: ", y_test.shape)
# Out:
# Number Observations in X_train dataset:  (5634, 46)
# Number Observations in y_train dataset:  (5634,)
# Number Observations in X_test dataset:  (1409, 46)
# Number Observations in y_test dataset:  (1409,)

# %%
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))

sm = SMOTE(random_state=2)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res==0)))
# Out:
# Before OverSampling, counts of label '0': 4133
#
# After OverSampling, the shape of train_X: (8266, 46)
# After OverSampling, the shape of train_y: (8266,)
#
# After OverSampling, counts of label '1': 4133
# After OverSampling, counts of label '0': 4133

# %% [markdown]
# We are just oversampling our train data and test data is still the same.

# %%
# Resampled data after SMOTE
pd.value_counts(y_train_res).plot.bar()
plt.title('Churn class histogram after SMOTE in train data')
plt.xlabel('Churn')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
pd.value_counts(y_test).plot.bar()
plt.title('Churn class histogram for test data')
plt.xlabel('Churn')
plt.ylabel('Frequency')

# Here we can see, data is still the same !!
# Out:
# Text(0, 0.5, 'Frequency')

# %%
from sklearn.preprocessing import StandardScaler
scaled_train = StandardScaler().fit_transform(X_train_res)
scaled_test = StandardScaler().fit_transform(X_test)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))
scaler.fit(X_train_res)
scaled_train = pd.DataFrame(scaler.transform(X_train_res))

scaler.fit(X_test)
scaled_test = pd.DataFrame(scaler.transform(X_test))

# %% [markdown]
# <p style="color:DodgerBlue; "> In this section we have successfully scaled our data and now we can proceed to data modeling part.
# </p><br> <br> <br> <br>
#
# <br><h2>Step 4: Data Modeling and Performance Evaluation <br> </h2>

# %% [markdown]
# <h3> Model 1  : Decision Trees </h3>

# %%
from sklearn import tree

# %%
clf_dt = tree.DecisionTreeClassifier(random_state=9)
clf_dt = clf_dt.fit(scaled_train, y_train_res)

# %%
plt.figure(figsize = (15,10))
tree.plot_tree(clf_dt, filled = True)

# below you can scroll and see a truly overfitted Decision Tree
# Out:
# [Text(0.290977127890386, 0.9814814814814815, 'x[37] <= 0.5\ngini = 0.5\nsamples = 8266\nvalue = [4133, 4133]'),
#  Text(0.09775278006589785, 0.9444444444444444, 'x[17] <= 0.5\ngini = 0.184\nsamples = 2631\nvalue = [2361, 270]'),
#  Text(0.056767033419628146, 0.9074074074074074, 'x[19] <= 0.5\ngini = 0.075\nsamples = 1762\nvalue = [1693, 69]'),
#  Text(0.040914038597317015, 0.8703703703703703, 'x[44] <= 0.5\ngini = 0.049\nsamples = 1443\nvalue = [1407, 36]'),
#  Text(0.026873970345963755, 0.8333333333333334, 'x[1] <= 0.738\ngini = 0.036\nsamples = 1321\nvalue = [1297, 24]'),
#  Text(0.02050482466462697, 0.7962962962962963, 'x[1] <= 0.442\ngini = 0.034\nsamples = 1317\nvalue = [1294, 23]'),
#  Text(0.010590727229936456, 0.7592592592592593, 'x[2] <= 0.002\ngini = 0.021\nsamples = 949\nvalue = [939, 10]'),
#  Text(0.008707931277947752, 0.7222222222222222, 'x[2] <= 0.002\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.007766533301953401, 0.6851851851851852, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.009649329253942103, 0.6851851851851852, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01247352318192516, 0.7222222222222222, 'x[0] <= 0.826\ngini = 0.019\nsamples = 942\nvalue = [933, 9]'),
#  Text(0.011532125205930808, 0.6851851851851852, 'x[0] <= 0.729\ngini = 0.027\nsamples = 666\nvalue = [657, 9]'),
#  Text(0.007060484819957637, 0.6481481481481481, 'x[15] <= 0.5\ngini = 0.017\nsamples = 585\nvalue = [580, 5]'),
#  Text(0.0037655919039774064, 0.6111111111111112, 'x[2] <= 0.015\ngini = 0.008\nsamples = 482\nvalue = [480, 2]'),
#  Text(0.0018827959519887032, 0.5740740740740741, 'x[2] <= 0.014\ngini = 0.059\nsamples = 33\nvalue = [32, 1]'),
#  Text(0.0009413979759943516, 0.5370370370370371, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.002824193927983055, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.00564838785596611, 0.5740740740740741, 'x[2] <= 0.043\ngini = 0.004\nsamples = 449\nvalue = [448, 1]'),
#  Text(0.004706989879971758, 0.5370370370370371, 'x[2] <= 0.043\ngini = 0.021\nsamples = 96\nvalue = [95, 1]'),
#  Text(0.0037655919039774064, 0.5, 'gini = 0.0\nsamples = 95\nvalue = [95, 0]'),
#  Text(0.00564838785596611, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.006589785831960461, 0.5370370370370371, 'gini = 0.0\nsamples = 353\nvalue = [353, 0]'),
#  Text(0.010355377735937867, 0.6111111111111112, 'x[2] <= 0.084\ngini = 0.057\nsamples = 103\nvalue = [100, 3]'),
#  Text(0.009413979759943516, 0.5740740740740741, 'x[2] <= 0.076\ngini = 0.139\nsamples = 40\nvalue = [37, 3]'),
#  Text(0.008472581783949164, 0.5370370370370371, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(0.010355377735937867, 0.5370370370370371, 'x[1] <= 0.074\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.009413979759943516, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.01129677571193222, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.01129677571193222, 0.5740740740740741, 'gini = 0.0\nsamples = 63\nvalue = [63, 0]'),
#  Text(0.016003765591903977, 0.6481481481481481, 'x[1] <= 0.025\ngini = 0.094\nsamples = 81\nvalue = [77, 4]'),
#  Text(0.014120969639915274, 0.6111111111111112, 'x[0] <= 0.812\ngini = 0.043\nsamples = 46\nvalue = [45, 1]'),
#  Text(0.013179571663920923, 0.5740740740740741, 'gini = 0.0\nsamples = 41\nvalue = [41, 0]'),
#  Text(0.015062367615909626, 0.5740740740740741, 'x[1] <= 0.012\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.014120969639915274, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.016003765591903977, 0.5370370370370371, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.01788656154389268, 0.6111111111111112, 'x[2] <= 0.123\ngini = 0.157\nsamples = 35\nvalue = [32, 3]'),
#  Text(0.016945163567898328, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01882795951988703, 0.5740740740740741, 'x[3] <= 0.5\ngini = 0.111\nsamples = 34\nvalue = [32, 2]'),
#  Text(0.01788656154389268, 0.5370370370370371, 'x[7] <= 0.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.016945163567898328, 0.5, 'x[2] <= 0.151\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.016003765591903977, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01788656154389268, 0.46296296296296297, 'x[30] <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.016945163567898328, 0.42592592592592593, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.01882795951988703, 0.42592592592592593, 'x[13] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.01788656154389268, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.019769357495881382, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01882795951988703, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.019769357495881382, 0.5370370370370371, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.01341492115791951, 0.6851851851851852, 'gini = 0.0\nsamples = 276\nvalue = [276, 0]'),
#  Text(0.030418922099317486, 0.7592592592592593, 'x[1] <= 0.443\ngini = 0.068\nsamples = 368\nvalue = [355, 13]'),
#  Text(0.029477524123323134, 0.7222222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03136032007531184, 0.7222222222222222, 'x[38] <= 0.5\ngini = 0.063\nsamples = 367\nvalue = [355, 12]'),
#  Text(0.025417745351847494, 0.6851851851851852, 'x[1] <= 0.609\ngini = 0.023\nsamples = 253\nvalue = [250, 3]'),
#  Text(0.024476347375853143, 0.6481481481481481, 'x[1] <= 0.608\ngini = 0.049\nsamples = 120\nvalue = [117, 3]'),
#  Text(0.02353494939985879, 0.6111111111111112, 'x[24] <= 0.5\ngini = 0.033\nsamples = 119\nvalue = [117, 2]'),
#  Text(0.02259355142386444, 0.5740740740740741, 'x[2] <= 0.547\ngini = 0.102\nsamples = 37\nvalue = [35, 2]'),
#  Text(0.02165215344787009, 0.5370370370370371, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.02353494939985879, 0.5370370370370371, 'x[2] <= 0.556\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.02259355142386444, 0.5, 'x[0] <= 0.986\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.02165215344787009, 0.46296296296296297, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.02353494939985879, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.024476347375853143, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.024476347375853143, 0.5740740740740741, 'gini = 0.0\nsamples = 82\nvalue = [82, 0]'),
#  Text(0.025417745351847494, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.026359143327841845, 0.6481481481481481, 'gini = 0.0\nsamples = 133\nvalue = [133, 0]'),
#  Text(0.03730289479877618, 0.6851851851851852, 'x[1] <= 0.665\ngini = 0.145\nsamples = 114\nvalue = [105, 9]'),
#  Text(0.03224288067780654, 0.6481481481481481, 'x[2] <= 0.245\ngini = 0.121\nsamples = 108\nvalue = [101, 7]'),
#  Text(0.0291833372558249, 0.6111111111111112, 'x[36] <= 0.5\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.028241939279830548, 0.5740740740740741, 'x[43] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.027300541303836197, 0.5370370370370371, 'x[9] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.026359143327841845, 0.5, 'x[0] <= 0.312\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.025417745351847494, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.027300541303836197, 0.46296296296296297, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.028241939279830548, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0291833372558249, 0.5370370370370371, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03012473523181925, 0.5740740740740741, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.035302424099788184, 0.6111111111111112, 'x[1] <= 0.599\ngini = 0.087\nsamples = 88\nvalue = [84, 4]'),
#  Text(0.032007531183807954, 0.5740740740740741, 'x[42] <= 0.5\ngini = 0.03\nsamples = 65\nvalue = [64, 1]'),
#  Text(0.031066133207813602, 0.5370370370370371, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(0.032948929159802305, 0.5370370370370371, 'x[13] <= 0.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]'),
#  Text(0.032007531183807954, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.033890327135796657, 0.5, 'x[30] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.032948929159802305, 0.46296296296296297, 'x[0] <= 0.653\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.032007531183807954, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.033890327135796657, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03483172511179101, 0.46296296296296297, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03859731701576841, 0.5740740740740741, 'x[1] <= 0.601\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.03765591903977406, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.039538714991762765, 0.5370370370370371, 'x[25] <= 0.5\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.03765591903977406, 0.5, 'x[2] <= 0.365\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.03671452106377971, 0.46296296296296297, 'x[2] <= 0.349\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.03577312308778536, 0.42592592592592593, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.03765591903977406, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03859731701576841, 0.46296296296296297, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.04142151094375147, 0.5, 'x[0] <= 0.812\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.040480112967757116, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.042362908919745826, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.042362908919745826, 0.6481481481481481, 'x[0] <= 0.493\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.04142151094375147, 0.6111111111111112, 'x[0] <= 0.389\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.040480112967757116, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.042362908919745826, 0.5740740740740741, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04330430689574018, 0.6111111111111112, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.03324311602730054, 0.7962962962962963, 'x[5] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.03230171805130619, 0.7592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03418451400329489, 0.7592592592592593, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.054954106848670276, 0.8333333333333334, 'x[42] <= 0.5\ngini = 0.177\nsamples = 122\nvalue = [110, 12]'),
#  Text(0.054012708872675924, 0.7962962962962963, 'x[43] <= 0.5\ngini = 0.153\nsamples = 120\nvalue = [110, 10]'),
#  Text(0.05307131089668157, 0.7592592592592593, 'x[22] <= 0.5\ngini = 0.14\nsamples = 119\nvalue = [110, 9]'),
#  Text(0.048952694751706285, 0.7222222222222222, 'x[11] <= 0.5\ngini = 0.071\nsamples = 81\nvalue = [78, 3]'),
#  Text(0.04706989879971758, 0.6851851851851852, 'x[1] <= 0.022\ngini = 0.028\nsamples = 70\nvalue = [69, 1]'),
#  Text(0.04612850082372323, 0.6481481481481481, 'x[1] <= 0.021\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.04518710284772888, 0.6111111111111112, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.04706989879971758, 0.6111111111111112, 'x[3] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04612850082372323, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.048011296775711934, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.048011296775711934, 0.6481481481481481, 'gini = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(0.05083549070369499, 0.6851851851851852, 'x[1] <= 0.255\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.04989409272770064, 0.6481481481481481, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05177688867968934, 0.6481481481481481, 'x[1] <= 0.407\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.05083549070369499, 0.6111111111111112, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.05271828665568369, 0.6111111111111112, 'x[8] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05177688867968934, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05365968463167804, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05718992704165686, 0.7222222222222222, 'x[2] <= 0.038\ngini = 0.266\nsamples = 38\nvalue = [32, 6]'),
#  Text(0.05624852906566251, 0.6851851851851852, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05813132501765121, 0.6851851851851852, 'x[8] <= 0.5\ngini = 0.234\nsamples = 37\nvalue = [32, 5]'),
#  Text(0.05718992704165686, 0.6481481481481481, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.05907272299364556, 0.6481481481481481, 'x[0] <= 0.938\ngini = 0.32\nsamples = 25\nvalue = [20, 5]'),
#  Text(0.05813132501765121, 0.6111111111111112, 'x[0] <= 0.847\ngini = 0.388\nsamples = 19\nvalue = [14, 5]'),
#  Text(0.055542480583666745, 0.5740740740740741, 'x[6] <= 0.5\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.05318898564368087, 0.5370370370370371, 'x[1] <= 0.657\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.051306189691692164, 0.5, 'x[2] <= 0.142\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.05036479171569781, 0.46296296296296297, 'x[11] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04942339373970346, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.051306189691692164, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.052247587667686515, 0.46296296296296297, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.05507178159566957, 0.5, 'x[0] <= 0.736\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05413038361967522, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05601317957166392, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.057895975523652624, 0.5370370370370371, 'x[13] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05695457754765827, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.058837373499646975, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06072016945163568, 0.5740740740740741, 'x[27] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.059778771475641326, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06166156742763003, 0.5370370370370371, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.060014120969639914, 0.6111111111111112, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.054954106848670276, 0.7592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05589550482466463, 0.7962962962962963, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07262002824193928, 0.8703703703703703, 'x[21] <= 0.5\ngini = 0.185\nsamples = 319\nvalue = [286, 33]'),
#  Text(0.07167863026594493, 0.8333333333333334, 'x[38] <= 0.5\ngini = 0.158\nsamples = 313\nvalue = [286, 27]'),
#  Text(0.06377971287361732, 0.7962962962962963, 'x[30] <= 0.5\ngini = 0.048\nsamples = 123\nvalue = [120, 3]'),
#  Text(0.06283831489762297, 0.7592592592592593, 'x[0] <= 0.972\ngini = 0.175\nsamples = 31\nvalue = [28, 3]'),
#  Text(0.060955518945634266, 0.7222222222222222, 'x[2] <= 0.604\ngini = 0.077\nsamples = 25\nvalue = [24, 1]'),
#  Text(0.060014120969639914, 0.6851851851851852, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.06189691692162862, 0.6851851851851852, 'x[1] <= 0.62\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.060955518945634266, 0.6481481481481481, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06283831489762297, 0.6481481481481481, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06472111084961167, 0.7222222222222222, 'x[12] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.06377971287361732, 0.6851851851851852, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06566250882560602, 0.6851851851851852, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.06472111084961167, 0.7592592592592593, 'gini = 0.0\nsamples = 92\nvalue = [92, 0]'),
#  Text(0.07957754765827253, 0.7962962962962963, 'x[2] <= 0.599\ngini = 0.221\nsamples = 190\nvalue = [166, 24]'),
#  Text(0.07863614968227818, 0.7592592592592593, 'x[41] <= 0.5\ngini = 0.207\nsamples = 188\nvalue = [166, 22]'),
#  Text(0.07036949870557778, 0.7222222222222222, 'x[0] <= 0.181\ngini = 0.082\nsamples = 70\nvalue = [67, 3]'),
#  Text(0.06754530477759473, 0.6851851851851852, 'x[2] <= 0.078\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.06660390680160037, 0.6481481481481481, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.06848670275358908, 0.6481481481481481, 'x[44] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06754530477759473, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06942810072958343, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07319369263356083, 0.6851851851851852, 'x[1] <= 0.153\ngini = 0.032\nsamples = 61\nvalue = [60, 1]'),
#  Text(0.07225229465756648, 0.6481481481481481, 'x[0] <= 0.625\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.07131089668157213, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07319369263356083, 0.6111111111111112, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07413509060955518, 0.6481481481481481, 'gini = 0.0\nsamples = 57\nvalue = [57, 0]'),
#  Text(0.08690280065897858, 0.7222222222222222, 'x[2] <= 0.382\ngini = 0.27\nsamples = 118\nvalue = [99, 19]'),
#  Text(0.08178394916450929, 0.6851851851851852, 'x[1] <= 0.409\ngini = 0.32\nsamples = 90\nvalue = [72, 18]'),
#  Text(0.07601788656154389, 0.6481481481481481, 'x[2] <= 0.374\ngini = 0.201\nsamples = 53\nvalue = [47, 6]'),
#  Text(0.07507648858554954, 0.6111111111111112, 'x[15] <= 0.5\ngini = 0.174\nsamples = 52\nvalue = [47, 5]'),
#  Text(0.07225229465756648, 0.5740740740740741, 'x[1] <= 0.332\ngini = 0.124\nsamples = 45\nvalue = [42, 3]'),
#  Text(0.07131089668157213, 0.5370370370370371, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.07319369263356083, 0.5370370370370371, 'x[1] <= 0.358\ngini = 0.278\nsamples = 18\nvalue = [15, 3]'),
#  Text(0.07225229465756648, 0.5, 'x[9] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.07131089668157213, 0.46296296296296297, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07319369263356083, 0.46296296296296297, 'x[45] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.07225229465756648, 0.42592592592592593, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07413509060955518, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07413509060955518, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.07790068251353259, 0.5740740740740741, 'x[2] <= 0.134\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.07695928453753824, 0.5370370370370371, 'x[24] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07601788656154389, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07790068251353259, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07884208048952694, 0.5370370370370371, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.07695928453753824, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0875500117674747, 0.6481481481481481, 'x[3] <= 0.5\ngini = 0.438\nsamples = 37\nvalue = [25, 12]'),
#  Text(0.08496116733349024, 0.6111111111111112, 'x[0] <= 0.493\ngini = 0.497\nsamples = 24\nvalue = [13, 11]'),
#  Text(0.08260767239350435, 0.5740740740740741, 'x[0] <= 0.257\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.08072487644151564, 0.5370370370370371, 'x[27] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.0797834784655213, 0.5, 'x[28] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07884208048952694, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08072487644151564, 0.46296296296296297, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08166627441751, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08449046834549306, 0.5370370370370371, 'x[45] <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.08354907036949871, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.08543186632148742, 0.5, 'x[0] <= 0.444\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.08449046834549306, 0.46296296296296297, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08637326429748177, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08731466227347612, 0.5740740740740741, 'x[2] <= 0.369\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.08637326429748177, 0.5370370370370371, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.08825606024947047, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09013885620145917, 0.6111111111111112, 'x[42] <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.08919745822546482, 0.5740740740740741, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.09108025417745352, 0.5740740740740741, 'x[31] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09013885620145917, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09202165215344787, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09202165215344787, 0.6851851851851852, 'x[22] <= 0.5\ngini = 0.069\nsamples = 28\nvalue = [27, 1]'),
#  Text(0.09108025417745352, 0.6481481481481481, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.09296305012944223, 0.6481481481481481, 'x[27] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.09202165215344787, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09390444810543658, 0.6111111111111112, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.08051894563426688, 0.7592592592592593, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07356142621793363, 0.8333333333333334, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.13873852671216758, 0.9074074074074074, 'x[16] <= 0.5\ngini = 0.356\nsamples = 869\nvalue = [668, 201]'),
#  Text(0.13779712873617322, 0.8703703703703703, 'x[38] <= 0.5\ngini = 0.339\nsamples = 852\nvalue = [668, 184]'),
#  Text(0.11520357731230878, 0.8333333333333334, 'x[19] <= 0.5\ngini = 0.174\nsamples = 354\nvalue = [320, 34]'),
#  Text(0.10425982584137444, 0.7962962962962963, 'x[0] <= 0.951\ngini = 0.093\nsamples = 205\nvalue = [195, 10]'),
#  Text(0.09861143798540833, 0.7592592592592593, 'x[1] <= 0.87\ngini = 0.191\nsamples = 75\nvalue = [67, 8]'),
#  Text(0.09767004000941398, 0.7222222222222222, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.09955283596140269, 0.7222222222222222, 'x[30] <= 0.5\ngini = 0.303\nsamples = 43\nvalue = [35, 8]'),
#  Text(0.09578724405742528, 0.6851851851851852, 'x[2] <= 0.804\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.09484584608143093, 0.6481481481481481, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.09672864203341963, 0.6481481481481481, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.10331842786538009, 0.6851851851851852, 'x[0] <= 0.917\ngini = 0.234\nsamples = 37\nvalue = [32, 5]'),
#  Text(0.09861143798540833, 0.6481481481481481, 'x[7] <= 0.5\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.09767004000941398, 0.6111111111111112, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.09955283596140269, 0.6111111111111112, 'x[25] <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.09767004000941398, 0.5740740740740741, 'x[43] <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.09672864203341963, 0.5370370370370371, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.09861143798540833, 0.5370370370370371, 'x[24] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.09767004000941398, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09955283596140269, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10143563191339139, 0.5740740740740741, 'x[1] <= 0.901\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10049423393739704, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10237702988938574, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10802541774535185, 0.6481481481481481, 'x[42] <= 0.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.1070840197693575, 0.6111111111111112, 'x[9] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.1052012238173688, 0.5740740740740741, 'x[2] <= 0.815\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.10425982584137444, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10614262179336315, 0.5370370370370371, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1089668157213462, 0.5740740740740741, 'x[1] <= 0.974\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.10802541774535185, 0.5370370370370371, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10990821369734055, 0.5370370370370371, 'x[1] <= 0.987\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1089668157213462, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1108496116733349, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1089668157213462, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10990821369734055, 0.7592592592592593, 'x[2] <= 0.766\ngini = 0.03\nsamples = 130\nvalue = [128, 2]'),
#  Text(0.10802541774535185, 0.7222222222222222, 'x[1] <= 0.735\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.1070840197693575, 0.6851851851851852, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.1089668157213462, 0.6851851851851852, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11179100964932925, 0.7222222222222222, 'x[24] <= 0.5\ngini = 0.016\nsamples = 121\nvalue = [120, 1]'),
#  Text(0.1108496116733349, 0.6851851851851852, 'x[7] <= 0.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.10990821369734055, 0.6481481481481481, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.11179100964932925, 0.6481481481481481, 'x[40] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1108496116733349, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1127324076253236, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1127324076253236, 0.6851851851851852, 'gini = 0.0\nsamples = 103\nvalue = [103, 0]'),
#  Text(0.1261473287832431, 0.7962962962962963, 'x[21] <= 0.5\ngini = 0.27\nsamples = 149\nvalue = [125, 24]'),
#  Text(0.12520593080724876, 0.7592592592592593, 'x[2] <= 0.841\ngini = 0.246\nsamples = 146\nvalue = [125, 21]'),
#  Text(0.11979289244528124, 0.7222222222222222, 'x[0] <= 0.854\ngini = 0.147\nsamples = 100\nvalue = [92, 8]'),
#  Text(0.11743939750529536, 0.6851851851851852, 'x[0] <= 0.84\ngini = 0.258\nsamples = 46\nvalue = [39, 7]'),
#  Text(0.11555660155330666, 0.6481481481481481, 'x[3] <= 0.5\ngini = 0.206\nsamples = 43\nvalue = [38, 5]'),
#  Text(0.11461520357731231, 0.6111111111111112, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.11649799952930101, 0.6111111111111112, 'x[0] <= 0.688\ngini = 0.32\nsamples = 25\nvalue = [20, 5]'),
#  Text(0.11461520357731231, 0.5740740740740741, 'x[34] <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.11367380560131796, 0.5370370370370371, 'x[13] <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.1127324076253236, 0.5, 'x[0] <= 0.472\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11179100964932925, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11367380560131796, 0.46296296296296297, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11461520357731231, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.11555660155330666, 0.5370370370370371, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11838079548128971, 0.5740740740740741, 'x[44] <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.11743939750529536, 0.5370370370370371, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.11932219345728406, 0.5370370370370371, 'x[2] <= 0.641\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.11838079548128971, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12026359143327842, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11932219345728406, 0.6481481481481481, 'x[31] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11838079548128971, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12026359143327842, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12214638738526712, 0.6851851851851852, 'x[0] <= 0.979\ngini = 0.036\nsamples = 54\nvalue = [53, 1]'),
#  Text(0.12120498940927277, 0.6481481481481481, 'gini = 0.0\nsamples = 41\nvalue = [41, 0]'),
#  Text(0.12308778536126147, 0.6481481481481481, 'x[42] <= 0.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.12214638738526712, 0.6111111111111112, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.12402918333725582, 0.6111111111111112, 'x[22] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12308778536126147, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12497058131325017, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13061896916921628, 0.7222222222222222, 'x[28] <= 0.5\ngini = 0.405\nsamples = 46\nvalue = [33, 13]'),
#  Text(0.12779477524123323, 0.6851851851851852, 'x[2] <= 0.844\ngini = 0.185\nsamples = 29\nvalue = [26, 3]'),
#  Text(0.12685337726523888, 0.6481481481481481, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12873617321722758, 0.6481481481481481, 'x[2] <= 0.886\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.12779477524123323, 0.6111111111111112, 'x[2] <= 0.885\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.12685337726523888, 0.5740740740740741, 'x[0] <= 0.951\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.12591197928924452, 0.5370370370370371, 'x[0] <= 0.938\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.12497058131325017, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12685337726523888, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12779477524123323, 0.5370370370370371, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.12873617321722758, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12967757119322193, 0.6111111111111112, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.13344316309719934, 0.6851851851851852, 'x[2] <= 0.879\ngini = 0.484\nsamples = 17\nvalue = [7, 10]'),
#  Text(0.13250176512120498, 0.6481481481481481, 'x[10] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.13156036714521063, 0.6111111111111112, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.13344316309719934, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1343845610731937, 0.6481481481481481, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.12708872675923746, 0.7592592592592593, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.16039068016003766, 0.8333333333333334, 'x[39] <= 0.5\ngini = 0.421\nsamples = 498\nvalue = [348, 150]'),
#  Text(0.1594492821840433, 0.7962962962962963, 'x[33] <= 0.5\ngini = 0.36\nsamples = 455\nvalue = [348, 107]'),
#  Text(0.13932690044716403, 0.7592592592592593, 'x[1] <= 0.522\ngini = 0.136\nsamples = 109\nvalue = [101, 8]'),
#  Text(0.1362673570251824, 0.7222222222222222, 'x[0] <= 0.458\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13532595904918804, 0.6851851851851852, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13720875500117674, 0.6851851851851852, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14238644386914567, 0.7222222222222222, 'x[45] <= 0.5\ngini = 0.122\nsamples = 107\nvalue = [100, 7]'),
#  Text(0.13909155095316544, 0.6851851851851852, 'x[2] <= 0.72\ngini = 0.096\nsamples = 99\nvalue = [94, 5]'),
#  Text(0.13720875500117674, 0.6481481481481481, 'x[44] <= 0.5\ngini = 0.065\nsamples = 89\nvalue = [86, 3]'),
#  Text(0.1362673570251824, 0.6111111111111112, 'gini = 0.0\nsamples = 60\nvalue = [60, 0]'),
#  Text(0.1381501529771711, 0.6111111111111112, 'x[1] <= 0.804\ngini = 0.185\nsamples = 29\nvalue = [26, 3]'),
#  Text(0.13720875500117674, 0.5740740740740741, 'x[0] <= 0.924\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.13532595904918804, 0.5370370370370371, 'x[1] <= 0.674\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.1343845610731937, 0.5, 'x[0] <= 0.799\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.13344316309719934, 0.46296296296296297, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.13532595904918804, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1362673570251824, 0.5, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.13909155095316544, 0.5370370370370371, 'x[30] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1381501529771711, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1400329489291598, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13909155095316544, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14097434690515415, 0.6481481481481481, 'x[25] <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.1400329489291598, 0.6111111111111112, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.1419157448811485, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1456813367851259, 0.6851851851851852, 'x[13] <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.14473993880913155, 0.6481481481481481, 'x[2] <= 0.478\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1437985408331372, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1456813367851259, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14662273476112025, 0.6481481481481481, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.17957166392092258, 0.7592592592592593, 'x[31] <= 0.5\ngini = 0.409\nsamples = 346\nvalue = [247, 99]'),
#  Text(0.17863026594492823, 0.7222222222222222, 'x[44] <= 0.5\ngini = 0.399\nsamples = 341\nvalue = [247, 94]'),
#  Text(0.16286184984702282, 0.6851851851851852, 'x[36] <= 0.5\ngini = 0.338\nsamples = 200\nvalue = [157, 43]'),
#  Text(0.16192045187102846, 0.6481481481481481, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(0.16380324782301717, 0.6481481481481481, 'x[1] <= 0.988\ngini = 0.376\nsamples = 171\nvalue = [128, 43]'),
#  Text(0.16286184984702282, 0.6111111111111112, 'x[2] <= 0.739\ngini = 0.367\nsamples = 169\nvalue = [128, 41]'),
#  Text(0.1518004236290892, 0.5740740740740741, 'x[2] <= 0.55\ngini = 0.416\nsamples = 112\nvalue = [79, 33]'),
#  Text(0.1437985408331372, 0.5370370370370371, 'x[8] <= 0.5\ngini = 0.268\nsamples = 44\nvalue = [37, 7]'),
#  Text(0.1419157448811485, 0.5, 'x[3] <= 0.5\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(0.14097434690515415, 0.46296296296296297, 'x[15] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.1400329489291598, 0.42592592592592593, 'x[0] <= 0.451\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.13909155095316544, 0.3888888888888889, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14097434690515415, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1419157448811485, 0.42592592592592593, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.14285714285714285, 0.46296296296296297, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.1456813367851259, 0.5, 'x[2] <= 0.477\ngini = 0.408\nsamples = 21\nvalue = [15, 6]'),
#  Text(0.14473993880913155, 0.46296296296296297, 'x[3] <= 0.5\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.1437985408331372, 0.42592592592592593, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1456813367851259, 0.42592592592592593, 'x[6] <= 0.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.1437985408331372, 0.3888888888888889, 'x[43] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.14285714285714285, 0.35185185185185186, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.14473993880913155, 0.35185185185185186, 'x[27] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1437985408331372, 0.3148148148148148, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1456813367851259, 0.3148148148148148, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1475641327371146, 0.3888888888888889, 'x[43] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.14662273476112025, 0.35185185185185186, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14850553071310896, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14662273476112025, 0.46296296296296297, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.15980230642504117, 0.5370370370370371, 'x[7] <= 0.5\ngini = 0.472\nsamples = 68\nvalue = [42, 26]'),
#  Text(0.15509531654506942, 0.5, 'x[2] <= 0.576\ngini = 0.411\nsamples = 45\nvalue = [32, 13]'),
#  Text(0.151329724641092, 0.46296296296296297, 'x[15] <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.15038832666509766, 0.42592592592592593, 'x[9] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.1494469286891033, 0.3888888888888889, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.151329724641092, 0.3888888888888889, 'x[28] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.15038832666509766, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15227112261708636, 0.35185185185185186, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15227112261708636, 0.42592592592592593, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.15886090844904682, 0.46296296296296297, 'x[2] <= 0.736\ngini = 0.339\nsamples = 37\nvalue = [29, 8]'),
#  Text(0.15791951047305247, 0.42592592592592593, 'x[2] <= 0.687\ngini = 0.313\nsamples = 36\nvalue = [29, 7]'),
#  Text(0.15697811249705812, 0.3888888888888889, 'x[2] <= 0.658\ngini = 0.403\nsamples = 25\nvalue = [18, 7]'),
#  Text(0.15415391856907507, 0.35185185185185186, 'x[43] <= 0.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.15321252059308071, 0.3148148148148148, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.15509531654506942, 0.3148148148148148, 'x[1] <= 0.814\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.15415391856907507, 0.2777777777777778, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.15603671452106377, 0.2777777777777778, 'x[2] <= 0.65\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.15509531654506942, 0.24074074074074073, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.15697811249705812, 0.24074074074074073, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15980230642504117, 0.35185185185185186, 'x[22] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.15886090844904682, 0.3148148148148148, 'x[2] <= 0.666\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.15791951047305247, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15980230642504117, 0.2777777777777778, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16074370440103553, 0.3148148148148148, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.15886090844904682, 0.3888888888888889, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.15980230642504117, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16450929630501293, 0.5, 'x[30] <= 0.5\ngini = 0.491\nsamples = 23\nvalue = [10, 13]'),
#  Text(0.16262650035302423, 0.46296296296296297, 'x[2] <= 0.622\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.16168510237702988, 0.42592592592592593, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.16356789832901858, 0.42592592592592593, 'x[19] <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.16262650035302423, 0.3888888888888889, 'x[27] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.16168510237702988, 0.35185185185185186, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16356789832901858, 0.35185185185185186, 'x[22] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16262650035302423, 0.3148148148148148, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16450929630501293, 0.3148148148148148, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16450929630501293, 0.3888888888888889, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.16639209225700163, 0.46296296296296297, 'x[1] <= 0.873\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.16545069428100728, 0.42592592592592593, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.167333490232996, 0.42592592592592593, 'x[19] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16639209225700163, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16827488820899036, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17392327606495647, 0.5740740740740741, 'x[1] <= 0.966\ngini = 0.241\nsamples = 57\nvalue = [49, 8]'),
#  Text(0.17204048011296777, 0.5370370370370371, 'x[19] <= 0.5\ngini = 0.177\nsamples = 51\nvalue = [46, 5]'),
#  Text(0.17109908213697342, 0.5, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.17298187808896212, 0.5, 'x[0] <= 0.965\ngini = 0.257\nsamples = 33\nvalue = [28, 5]'),
#  Text(0.17204048011296777, 0.46296296296296297, 'x[2] <= 0.853\ngini = 0.33\nsamples = 24\nvalue = [19, 5]'),
#  Text(0.17109908213697342, 0.42592592592592593, 'x[1] <= 0.873\ngini = 0.287\nsamples = 23\nvalue = [19, 4]'),
#  Text(0.17015768416097907, 0.3888888888888889, 'x[1] <= 0.867\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.16827488820899036, 0.35185185185185186, 'x[0] <= 0.91\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.167333490232996, 0.3148148148148148, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.16921628618498472, 0.3148148148148148, 'x[9] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.16827488820899036, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17015768416097907, 0.2777777777777778, 'x[4] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.16921628618498472, 0.24074074074074073, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.17109908213697342, 0.24074074074074073, 'x[1] <= 0.859\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.17015768416097907, 0.2037037037037037, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17204048011296777, 0.2037037037037037, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17204048011296777, 0.35185185185185186, 'x[13] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.17109908213697342, 0.3148148148148148, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17298187808896212, 0.3148148148148148, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17204048011296777, 0.3888888888888889, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.17298187808896212, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17392327606495647, 0.46296296296296297, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.17580607201694518, 0.5370370370370371, 'x[1] <= 0.97\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.17486467404095082, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17674746999293953, 0.5, 'x[3] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.17580607201694518, 0.46296296296296297, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.17768886796893388, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16474464579901152, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19439868204283361, 0.6851851851851852, 'x[42] <= 0.5\ngini = 0.462\nsamples = 141\nvalue = [90, 51]'),
#  Text(0.19345728406683926, 0.6481481481481481, 'x[43] <= 0.5\ngini = 0.441\nsamples = 134\nvalue = [90, 44]'),
#  Text(0.1925158860908449, 0.6111111111111112, 'x[0] <= 0.958\ngini = 0.422\nsamples = 129\nvalue = [90, 39]'),
#  Text(0.19157448811485056, 0.5740740740740741, 'x[0] <= 0.799\ngini = 0.439\nsamples = 120\nvalue = [81, 39]'),
#  Text(0.18427865380089434, 0.5370370370370371, 'x[2] <= 0.361\ngini = 0.378\nsamples = 75\nvalue = [56, 19]'),
#  Text(0.18051306189691693, 0.5, 'x[0] <= 0.444\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(0.17957166392092258, 0.46296296296296297, 'x[1] <= 0.851\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.17863026594492823, 0.42592592592592593, 'x[25] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.17768886796893388, 0.3888888888888889, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.17957166392092258, 0.3888888888888889, 'x[41] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.17863026594492823, 0.35185185185185186, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.18051306189691693, 0.35185185185185186, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.18051306189691693, 0.42592592592592593, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.18145445987291128, 0.46296296296296297, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.18804424570487174, 0.5, 'x[45] <= 0.5\ngini = 0.316\nsamples = 61\nvalue = [49, 12]'),
#  Text(0.1871028477288774, 0.46296296296296297, 'x[1] <= 0.898\ngini = 0.299\nsamples = 60\nvalue = [49, 11]'),
#  Text(0.18427865380089434, 0.42592592592592593, 'x[0] <= 0.465\ngini = 0.237\nsamples = 51\nvalue = [44, 7]'),
#  Text(0.1833372558249, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1852200517768887, 0.3888888888888889, 'x[28] <= 0.5\ngini = 0.211\nsamples = 50\nvalue = [44, 6]'),
#  Text(0.18239585784890563, 0.35185185185185186, 'x[25] <= 0.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.18145445987291128, 0.3148148148148148, 'x[2] <= 0.524\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.17957166392092258, 0.2777777777777778, 'x[0] <= 0.514\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.17863026594492823, 0.24074074074074073, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18051306189691693, 0.24074074074074073, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1833372558249, 0.2777777777777778, 'x[2] <= 0.643\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.18239585784890563, 0.24074074074074073, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.18427865380089434, 0.24074074074074073, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1833372558249, 0.3148148148148148, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.18804424570487174, 0.35185185185185186, 'x[25] <= 0.5\ngini = 0.124\nsamples = 30\nvalue = [28, 2]'),
#  Text(0.1871028477288774, 0.3148148148148148, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.1889856436808661, 0.3148148148148148, 'x[36] <= 0.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.1871028477288774, 0.2777777777777778, 'x[2] <= 0.562\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.18616144975288304, 0.24074074074074073, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18804424570487174, 0.24074074074074073, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1908684396328548, 0.2777777777777778, 'x[19] <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.18992704165686045, 0.24074074074074073, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.19180983760884915, 0.24074074074074073, 'x[13] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1908684396328548, 0.2037037037037037, 'x[4] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.18992704165686045, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19180983760884915, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1927512355848435, 0.2037037037037037, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18992704165686045, 0.42592592592592593, 'x[1] <= 0.917\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.1889856436808661, 0.3888888888888889, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1908684396328548, 0.3888888888888889, 'x[9] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.18992704165686045, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19180983760884915, 0.35185185185185186, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.1889856436808661, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...
#  Text(0.31654506942810073, 0.3888888888888889, 'x[8] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3156036714521064, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3174864674040951, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31842786538008944, 0.3888888888888889, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3212520593080725, 0.42592592592592593, 'x[42] <= 0.5\ngini = 0.038\nsamples = 51\nvalue = [50, 1]'),
#  Text(0.32031066133207814, 0.3888888888888889, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]'),
#  Text(0.32219345728406684, 0.3888888888888889, 'x[0] <= 0.431\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.3212520593080725, 0.35185185185185186, 'x[10] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.32031066133207814, 0.3148148148148148, 'x[1] <= 0.012\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3193692633560838, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3212520593080725, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32219345728406684, 0.3148148148148148, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3231348552600612, 0.35185185185185186, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.32595904918804425, 0.46296296296296297, 'x[43] <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.3250176512120499, 0.42592592592592593, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.3269004471640386, 0.42592592592592593, 'x[8] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.32595904918804425, 0.3888888888888889, 'x[0] <= 0.646\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3250176512120499, 0.35185185185185186, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3269004471640386, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.32784184514003295, 0.3888888888888889, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3245469522240527, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3325488350200047, 0.5370370370370371, 'x[2] <= 0.252\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.330666039068016, 0.5, 'x[13] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.32972464109202165, 0.46296296296296297, 'x[41] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3287832431160273, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.330666039068016, 0.42592592592592593, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.33160743704401036, 0.46296296296296297, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3344316309719934, 0.5, 'x[1] <= 0.596\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.33349023299599906, 0.46296296296296297, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.33537302894798776, 0.46296296296296297, 'x[0] <= 0.597\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3344316309719934, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3363144269239821, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3299599905860202, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3438456107319369, 0.6851851851851852, 'x[25] <= 0.5\ngini = 0.361\nsamples = 89\nvalue = [68, 21]'),
#  Text(0.3400800188279595, 0.6481481481481481, 'x[42] <= 0.5\ngini = 0.136\nsamples = 41\nvalue = [38, 3]'),
#  Text(0.33913862085196517, 0.6111111111111112, 'x[1] <= 0.018\ngini = 0.095\nsamples = 40\nvalue = [38, 2]'),
#  Text(0.3381972228759708, 0.5740740740740741, 'x[2] <= 0.044\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.33725582489997646, 0.5370370370370371, 'x[1] <= 0.01\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.3363144269239821, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3381972228759708, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.33913862085196517, 0.5370370370370371, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3400800188279595, 0.5740740740740741, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.34102141680395387, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34761120263591433, 0.6481481481481481, 'x[9] <= 0.5\ngini = 0.469\nsamples = 48\nvalue = [30, 18]'),
#  Text(0.3429042127559426, 0.6111111111111112, 'x[4] <= 0.5\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.3419628147799482, 0.5740740740740741, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.3438456107319369, 0.5740740740740741, 'x[1] <= 0.488\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.3429042127559426, 0.5370370370370371, 'x[1] <= 0.309\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.3419628147799482, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3438456107319369, 0.5, 'x[30] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3429042127559426, 0.46296296296296297, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3447870087079313, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3447870087079313, 0.5370370370370371, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3523181925158861, 0.6111111111111112, 'x[40] <= 0.5\ngini = 0.498\nsamples = 32\nvalue = [17, 15]'),
#  Text(0.3485526006119087, 0.5740740740740741, 'x[8] <= 0.5\ngini = 0.432\nsamples = 19\nvalue = [13, 6]'),
#  Text(0.34666980465992, 0.5370370370370371, 'x[2] <= 0.071\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.3457284066839256, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.34761120263591433, 0.5, 'x[2] <= 0.09\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.34666980465992, 0.46296296296296297, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3485526006119087, 0.46296296296296297, 'x[3] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.34761120263591433, 0.42592592592592593, 'x[1] <= 0.424\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.34666980465992, 0.3888888888888889, 'x[15] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3457284066839256, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34761120263591433, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3485526006119087, 0.3888888888888889, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.34949399858790303, 0.42592592592592593, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3504353965638974, 0.5370370370370371, 'x[2] <= 0.116\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.34949399858790303, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.35137679453989173, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3560837844198635, 0.5740740740740741, 'x[0] <= 0.312\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.3542009884678748, 0.5370370370370371, 'x[8] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.35325959049188044, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.35514238644386914, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3579665803718522, 0.5370370370370371, 'x[0] <= 0.431\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.35702518239585784, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.35890797834784655, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.37244057425276533, 0.7222222222222222, 'x[13] <= 0.5\ngini = 0.437\nsamples = 62\nvalue = [42, 20]'),
#  Text(0.371499176276771, 0.6851851851851852, 'x[1] <= 0.357\ngini = 0.361\nsamples = 55\nvalue = [42, 13]'),
#  Text(0.36526241468580845, 0.6481481481481481, 'x[5] <= 0.5\ngini = 0.292\nsamples = 45\nvalue = [37, 8]'),
#  Text(0.3617321722758296, 0.6111111111111112, 'x[0] <= 0.389\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.36079077429983525, 0.5740740740740741, 'x[1] <= 0.12\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3598493763238409, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3617321722758296, 0.5370370370370371, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.36267357025182395, 0.5740740740740741, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.36879265709578724, 0.6111111111111112, 'x[1] <= 0.268\ngini = 0.229\nsamples = 38\nvalue = [33, 5]'),
#  Text(0.365497764179807, 0.5740740740740741, 'x[2] <= 0.025\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.3636149682278183, 0.5370370370370371, 'x[1] <= 0.118\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.36267357025182395, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.36455636620381265, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3673805601317957, 0.5370370370370371, 'x[42] <= 0.5\ngini = 0.077\nsamples = 25\nvalue = [24, 1]'),
#  Text(0.36643916215580136, 0.5, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.36832195810779006, 0.5, 'x[22] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.3673805601317957, 0.46296296296296297, 'x[10] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.36643916215580136, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36832195810779006, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3692633560837844, 0.46296296296296297, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.37208755001176747, 0.5740740740740741, 'x[1] <= 0.313\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.3711461520357731, 0.5370370370370371, 'x[41] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.37020475405977876, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.37208755001176747, 0.5, 'x[0] <= 0.701\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3711461520357731, 0.46296296296296297, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3730289479877618, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3730289479877618, 0.5370370370370371, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3777359378677336, 0.6481481481481481, 'x[1] <= 0.402\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.3767945398917392, 0.6111111111111112, 'x[34] <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.37585314191574487, 0.5740740740740741, 'x[2] <= 0.042\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.3749117439397505, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3767945398917392, 0.5370370370370371, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.3777359378677336, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3786773358437279, 0.6111111111111112, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3733819722287597, 0.6851851851851852, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4247322899505766, 0.7962962962962963, 'x[0] <= 0.604\ngini = 0.493\nsamples = 323\nvalue = [181, 142]'),
#  Text(0.40324193927983054, 0.7592592592592593, 'x[3] <= 0.5\ngini = 0.496\nsamples = 224\nvalue = [102, 122]'),
#  Text(0.3875617792421746, 0.7222222222222222, 'x[45] <= 0.5\ngini = 0.478\nsamples = 96\nvalue = [58, 38]'),
#  Text(0.38662038126618026, 0.6851851851851852, 'x[2] <= 0.048\ngini = 0.496\nsamples = 83\nvalue = [45, 38]'),
#  Text(0.381501529771711, 0.6481481481481481, 'x[41] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.3805601317957166, 0.6111111111111112, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.38244292774770533, 0.6111111111111112, 'x[2] <= 0.033\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.381501529771711, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3833843257236997, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3917392327606496, 0.6481481481481481, 'x[0] <= 0.118\ngini = 0.5\nsamples = 76\nvalue = [39, 37]'),
#  Text(0.38620851965168274, 0.6111111111111112, 'x[24] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.3852671216756884, 0.5740740740740741, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.3871499176276771, 0.5740740740740741, 'x[34] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.38620851965168274, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38809131560367144, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3972699458696164, 0.6111111111111112, 'x[33] <= 0.5\ngini = 0.495\nsamples = 69\nvalue = [38, 31]'),
#  Text(0.39185690750764884, 0.5740740740740741, 'x[1] <= 0.659\ngini = 0.45\nsamples = 38\nvalue = [25, 13]'),
#  Text(0.38997411155566014, 0.5370370370370371, 'x[0] <= 0.368\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.3890327135796658, 0.5, 'x[1] <= 0.627\ngini = 0.48\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.38809131560367144, 0.46296296296296297, 'x[28] <= 0.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.3871499176276771, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3890327135796658, 0.42592592592592593, 'x[1] <= 0.551\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.38809131560367144, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38997411155566014, 0.3888888888888889, 'x[5] <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.3890327135796658, 0.35185185185185186, 'x[10] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.38809131560367144, 0.3148148148148148, 'x[40] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3871499176276771, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3890327135796658, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.38997411155566014, 0.3148148148148148, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3909155095316545, 0.35185185185185186, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.38997411155566014, 0.46296296296296297, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3909155095316545, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.39373970345963755, 0.5370370370370371, 'x[43] <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.3927983054836432, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.3946811014356319, 0.5, 'x[0] <= 0.403\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.39373970345963755, 0.46296296296296297, 'x[30] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3927983054836432, 0.42592592592592593, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3946811014356319, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39562249941162625, 0.46296296296296297, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4026829842315839, 0.5740740740740741, 'x[1] <= 0.858\ngini = 0.487\nsamples = 31\nvalue = [13, 18]'),
#  Text(0.400329489291598, 0.5370370370370371, 'x[34] <= 0.5\ngini = 0.413\nsamples = 24\nvalue = [7, 17]'),
#  Text(0.3984466933396093, 0.5, 'x[0] <= 0.215\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.39750529536361495, 0.46296296296296297, 'x[0] <= 0.174\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3965638973876206, 0.42592592592592593, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3984466933396093, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39938809131560365, 0.46296296296296297, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.4022122852435867, 0.5, 'x[40] <= 0.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.40127088726759236, 0.46296296296296297, 'x[0] <= 0.222\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.400329489291598, 0.42592592592592593, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4022122852435867, 0.42592592592592593, 'x[2] <= 0.376\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.40127088726759236, 0.3888888888888889, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.40315368321958106, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.40315368321958106, 0.46296296296296297, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.40503647917156976, 0.5370370370370371, 'x[43] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  ...]

# %%
from sklearn.metrics import confusion_matrix
pred_dt_1=clf_dt.predict(scaled_train)
confusion_matrix(y_train_res,pred_dt_1)
pd.crosstab(y_train_res, pred_dt_1, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0     1   All
# True
# 0          4132     1  4133
# 1            13  4120  4133
# All        4145  4121  8266

# %%
pred_dt_2=clf_dt.predict(scaled_test)
confusion_matrix(y_test,pred_dt_2)
pd.crosstab(y_test, pred_dt_2, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0    1   All
# True
# 0           837  204  1041
# 1           187  181   368
# All        1024  385  1409

# %% [markdown]
# <br> <b>
# <p style="color:DodgerBlue; "> This is a clear example of overfitting where we are just getting 14 mis-classified points for
#     train data and for testing we have 611 mis-classified points
# </p><br> <br></b>

# %%
clf_dt = tree.DecisionTreeClassifier(random_state=9, max_depth=4)
clf_dt = clf_dt.fit(scaled_train, y_train_res)

# %%
plt.figure(figsize = (15,10))
tree.plot_tree(clf_dt, filled = True)

# below you can scroll and see a truly overfitted Decision Tree
# Out:
# [Text(0.49107142857142855, 0.9, 'x[37] <= 0.5\ngini = 0.5\nsamples = 8266\nvalue = [4133, 4133]'),
#  Text(0.26785714285714285, 0.7, 'x[17] <= 0.5\ngini = 0.184\nsamples = 2631\nvalue = [2361, 270]'),
#  Text(0.14285714285714285, 0.5, 'x[19] <= 0.5\ngini = 0.075\nsamples = 1762\nvalue = [1693, 69]'),
#  Text(0.07142857142857142, 0.3, 'x[44] <= 0.5\ngini = 0.049\nsamples = 1443\nvalue = [1407, 36]'),
#  Text(0.03571428571428571, 0.1, 'gini = 0.036\nsamples = 1321\nvalue = [1297, 24]'),
#  Text(0.10714285714285714, 0.1, 'gini = 0.177\nsamples = 122\nvalue = [110, 12]'),
#  Text(0.21428571428571427, 0.3, 'x[21] <= 0.5\ngini = 0.185\nsamples = 319\nvalue = [286, 33]'),
#  Text(0.17857142857142858, 0.1, 'gini = 0.158\nsamples = 313\nvalue = [286, 27]'),
#  Text(0.25, 0.1, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.39285714285714285, 0.5, 'x[16] <= 0.5\ngini = 0.356\nsamples = 869\nvalue = [668, 201]'),
#  Text(0.35714285714285715, 0.3, 'x[38] <= 0.5\ngini = 0.339\nsamples = 852\nvalue = [668, 184]'),
#  Text(0.32142857142857145, 0.1, 'gini = 0.174\nsamples = 354\nvalue = [320, 34]'),
#  Text(0.39285714285714285, 0.1, 'gini = 0.421\nsamples = 498\nvalue = [348, 150]'),
#  Text(0.42857142857142855, 0.3, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.7142857142857143, 0.7, 'x[19] <= 0.5\ngini = 0.431\nsamples = 5635\nvalue = [1772, 3863]'),
#  Text(0.5714285714285714, 0.5, 'x[0] <= 0.021\ngini = 0.476\nsamples = 1233\nvalue = [752, 481]'),
#  Text(0.5, 0.3, 'x[41] <= 0.5\ngini = 0.465\nsamples = 261\nvalue = [96, 165]'),
#  Text(0.4642857142857143, 0.1, 'gini = 0.498\nsamples = 142\nvalue = [67, 75]'),
#  Text(0.5357142857142857, 0.1, 'gini = 0.369\nsamples = 119\nvalue = [29, 90]'),
#  Text(0.6428571428571429, 0.3, 'x[38] <= 0.5\ngini = 0.439\nsamples = 972\nvalue = [656, 316]'),
#  Text(0.6071428571428571, 0.1, 'gini = 0.422\nsamples = 941\nvalue = [656, 285]'),
#  Text(0.6785714285714286, 0.1, 'gini = 0.0\nsamples = 31\nvalue = [0, 31]'),
#  Text(0.8571428571428571, 0.5, 'x[44] <= 0.5\ngini = 0.356\nsamples = 4402\nvalue = [1020, 3382]'),
#  Text(0.7857142857142857, 0.3, 'x[0] <= 0.104\ngini = 0.488\nsamples = 1275\nvalue = [537, 738]'),
#  Text(0.75, 0.1, 'gini = 0.375\nsamples = 525\nvalue = [131, 394]'),
#  Text(0.8214285714285714, 0.1, 'gini = 0.497\nsamples = 750\nvalue = [406, 344]'),
#  Text(0.9285714285714286, 0.3, 'x[22] <= 0.5\ngini = 0.261\nsamples = 3127\nvalue = [483, 2644]'),
#  Text(0.8928571428571429, 0.1, 'gini = 0.453\nsamples = 510\nvalue = [177, 333]'),
#  Text(0.9642857142857143, 0.1, 'gini = 0.207\nsamples = 2617\nvalue = [306, 2311]')]

# %%
pred_dt_3=clf_dt.predict(scaled_train)
confusion_matrix(y_train_res,pred_dt_3)
pd.crosstab(y_train_res, pred_dt_3, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0     1   All
# True
# 0          3423   710  4133
# 1           876  3257  4133
# All        4299  3967  8266

# %%
pred_dt_4=clf_dt.predict(scaled_test)
confusion_matrix(y_test,pred_dt_4)
pd.crosstab(y_test, pred_dt_4, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted    0    1   All
# True
# 0          840  201  1041
# 1          145  223   368
# All        985  424  1409

# %% [markdown]
# # <br> <b>
# <p style="color:DodgerBlue; "> Here our model is making way too many mistakes in training set but in test set, we just have 568 points at depth = 4 which is better than our previous overfitted model. We can do rigorous hyper-parameter tuning and get good results !!
# </p><br> <br><br></b>
#
# <h3> Model 2  : K-Nearest Neighbors </h3>

# %%
# Prediction for optimum k
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
k=[]
accuracy=[]
for i in range(1,40,2):
    knn=KNeighborsClassifier(n_neighbors=i)
    #fitting model with k=1,2,5....39 on x_train_knn
    knn.fit(scaled_train,y_train_res)
    #predicting on iris_cv
    pred=knn.predict(scaled_test)
    k.append(i)
    acc=accuracy_score(y_test,pred,normalize=True)*float(100)
    accuracy.append(acc)
    #Evaluationg Accuracy
    print("\n CV k,accuracy",(i,acc))
# For K=11 we are getting highest accuracy for train data. Also for K=3,5,9 are also worth looking into
# Out:
#  CV k,accuracy (1, 69.76579134137685)
#
#  CV k,accuracy (3, 73.24343506032646)
#
#  CV k,accuracy (5, 74.30801987224982)
#
#  CV k,accuracy (7, 74.73385379701917)
#
#  CV k,accuracy (9, 75.1596877217885)
#
#  CV k,accuracy (11, 75.44357700496806)
#
#  CV k,accuracy (13, 75.37260468417317)
#
#  CV k,accuracy (15, 75.51454932576294)
#
#  CV k,accuracy (17, 75.72746628814762)
#
#  CV k,accuracy (19, 75.94038325053229)
#
#  CV k,accuracy (21, 75.7984386089425)
#
#  CV k,accuracy (23, 75.58552164655784)
#
#  CV k,accuracy (25, 75.37260468417317)
#
#  CV k,accuracy (27, 75.01774308019871)
#
#  CV k,accuracy (29, 74.94677075940383)
#
#  CV k,accuracy (31, 74.94677075940383)
#
#  CV k,accuracy (33, 74.80482611781405)
#
#  CV k,accuracy (35, 74.66288147622427)
#
#  CV k,accuracy (37, 74.59190915542938)
#
#  CV k,accuracy (39, 74.73385379701917)

# %%
plt.plot(k,accuracy)
# for k =19,17 we are getting good scores on test data

# %%
#let us get the predictions using the classifier we had fit above
knn=KNeighborsClassifier(n_neighbors=19)
knn.fit(scaled_train,y_train_res)
pred=knn.predict(scaled_test)
confusion_matrix(y_test,pred)
pd.crosstab(y_test, pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted    0    1   All
# True
# 0          843  198  1041
# 1          141  227   368
# All        984  425  1409

# %%
#let us get the predictions using the classifier we had fit above
knn=KNeighborsClassifier(n_neighbors=15)
knn.fit(scaled_train,y_train_res)
pred=knn.predict(scaled_test)
confusion_matrix(y_test,pred)
pd.crosstab(y_test, pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted    0    1   All
# True
# 0          838  203  1041
# 1          142  226   368
# All        980  429  1409

# %% [markdown]
# <p style="color:DodgerBlue; "> We have equal rates of mis-classified points for both 19 and 17 NN i.e. 340 points which is overall performing better than our underfit decision tree with depth=4.
#     <br><br>
#     One thing to observe is that 19-NN model is giving low errors on predicting Churner which might be preferred
# </p><br> <br><br></b>
#
# <h3> Model 3  : Logistic Regression </h3>

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

parameters = {
    'C': np.linspace(0.001, 0.1, 1, 10)
             }
lr = LogisticRegression(random_state=9, max_iter=500)
clf = GridSearchCV(lr, parameters, cv=5, verbose=5, n_jobs=3)
clf.fit(scaled_train, y_train_res.ravel())
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GridSearchCV(cv=5, estimator=LogisticRegression(max_iter=500, random_state=9),
#              n_jobs=3, param_grid={'C': array([0.001])}, verbose=5)

# %%
clf.best_params_
# Out:
# {'C': 0.001}

# %%
lr1 = LogisticRegression(C=0.001,penalty='l2', verbose=5,random_state=9, max_iter=500)
lr1.fit(scaled_train, y_train_res.ravel())
# We are using Ridge Regression for this use case
# Out:
# LogisticRegression(C=0.001, max_iter=500, random_state=9, verbose=5)

# %%
pred=lr1.predict(scaled_test)
confusion_matrix(y_test,pred)
pd.crosstab(y_test, pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted    0    1   All
# True
# 0          780  261  1041
# 1           98  270   368
# All        878  531  1409

# %%
lr1 = LogisticRegression(max_iter=500)
lr1.fit(scaled_train, y_train_res)
# Out:
# LogisticRegression(max_iter=500)

# %%
pred=lr1.predict(scaled_test)
confusion_matrix(y_test,pred)
pd.crosstab(y_test, pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0    1   All
# True
# 0           916  125  1041
# 1           161  207   368
# All        1077  332  1409

# %%
lr1 = LogisticRegression(C=0.001,penalty='l2', random_state=9, max_iter=500)
lr1.fit(scaled_train, y_train_res.ravel())
# We are using Ridge Regression for this use case
# Out:
# LogisticRegression(C=0.001, max_iter=500, random_state=9)

# %%
pred=lr1.predict(scaled_test)
confusion_matrix(y_test,pred)
pd.crosstab(y_test, pred, rownames=['True'], colnames=['Predicted'], margins=True)

# For lower values of c, we are able to balance between predicting churners and non-churners
# Out:
# Predicted    0    1   All
# True
# 0          780  261  1041
# 1           98  270   368
# All        878  531  1409

# %%
lr1 = LogisticRegression(C=0.0005,penalty='l2', random_state=9, max_iter=500)
lr1.fit(scaled_train, y_train_res.ravel())
# We are using Ridge Regression for this use case
# Out:
# LogisticRegression(C=0.0005, max_iter=500, random_state=9)

# %%
pred=lr1.predict(scaled_test)
confusion_matrix(y_test,pred)
pd.crosstab(y_test, pred, rownames=['True'], colnames=['Predicted'], margins=True)

# For lower values of c, we are able to balance between predicting churners and non-churners
# Out:
# Predicted    0    1   All
# True
# 0          762  279  1041
# 1           93  275   368
# All        855  554  1409

# %%
lr1 = LogisticRegression(C=0.0001,penalty='l2', random_state=9, max_iter=500)
lr1.fit(scaled_train, y_train_res.ravel())
# We are using Ridge Regression for this use case
# Out:
# LogisticRegression(C=0.0001, max_iter=500, random_state=9)

# %%
pred=lr1.predict(scaled_test)
confusion_matrix(y_test,pred)
pd.crosstab(y_test, pred, rownames=['True'], colnames=['Predicted'], margins=True)

# For lower values of c, we are able to balance between predicting churners and non-churners
# Out:
# Predicted    0    1   All
# True
# 0          724  317  1041
# 1           84  284   368
# All        808  601  1409

# %% [markdown]
# <p style="color:DodgerBlue; "> For Basic LR model with 500 iterations we are getting best accuracy but
#      model is not able to classify churners well and is not appropriate.
#     <br><br>
#     One thing to observe here is that low value of c is able to predict churners better !
# </p><br> <br><br></b>
#
# <h3> Model 4  : Support Vector Machine </h3>

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)

# %%
# fitting the model for grid search
grid.fit(scaled_train, y_train_res)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.632 total time=   6.2s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.626 total time=   5.2s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.619 total time=   6.5s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.658 total time=   6.6s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.660 total time=   6.4s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.683 total time=   2.6s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.736 total time=   2.4s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.869 total time=   2.7s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.876 total time=   2.9s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.884 total time=   4.1s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.743 total time=   4.4s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.776 total time=   2.7s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.825 total time=   3.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.832 total time=   3.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.858 total time=   3.9s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.753 total time=   5.2s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.774 total time=   4.5s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.774 total time=   5.8s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.782 total time=   5.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.801 total time=   4.6s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.716 total time=   6.9s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.500 total time=   5.6s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.500 total time=   6.7s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.500 total time=   6.1s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.500 total time=   6.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.654 total time=   6.5s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.703 total time=   5.1s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.862 total time=   6.9s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.853 total time=   5.3s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.849 total time=   5.6s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.665 total time=   2.6s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.731 total time=   2.3s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.898 total time=   2.3s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.903 total time=   2.3s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.909 total time=   2.4s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.686 total time=   1.9s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.748 total time=   2.8s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.877 total time=   3.1s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.886 total time=   2.4s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.895 total time=   2.5s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.742 total time=   2.6s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.777 total time=   3.2s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.825 total time=   3.9s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.834 total time=   3.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.858 total time=   3.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.754 total time=   5.3s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.774 total time=   5.2s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.774 total time=   4.6s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.782 total time=   5.7s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.801 total time=   5.1s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.649 total time=   5.2s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.709 total time=   7.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.875 total time=   5.4s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.860 total time=   6.8s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.857 total time=   6.2s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.659 total time=   1.9s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.742 total time=   2.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.897 total time=   3.6s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.894 total time=   3.5s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.906 total time=   2.9s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.648 total time=   1.6s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.730 total time=   1.7s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.906 total time=   2.2s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.904 total time=   3.1s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.921 total time=   2.8s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.698 total time=   1.9s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.760 total time=   2.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.877 total time=   2.4s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.884 total time=   2.4s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.892 total time=   3.5s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.742 total time=   3.1s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.777 total time=   2.8s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.825 total time=   3.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.834 total time=   3.2s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.858 total time=   4.5s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.646 total time=   6.2s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.708 total time=   7.8s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.880 total time=   8.3s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.866 total time=   7.1s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.860 total time=   6.6s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.647 total time=   2.6s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.720 total time=   4.2s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.886 total time=   4.9s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.880 total time=   5.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.881 total time=   6.4s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.661 total time=   1.9s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.730 total time=   2.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.907 total time=   3.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.910 total time=   3.8s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.924 total time=   3.6s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.674 total time=   1.5s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.750 total time=   1.6s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.903 total time=   2.1s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.904 total time=   2.1s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.921 total time=   2.9s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.698 total time=   2.5s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.762 total time=   1.9s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.877 total time=   2.3s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.884 total time=   2.3s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.892 total time=   2.3s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.648 total time=   7.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.701 total time=   6.2s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.883 total time=   7.4s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.880 total time=   7.5s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.860 total time=   8.4s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.641 total time=   2.7s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.706 total time=   3.6s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.884 total time=   8.7s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.874 total time=   7.5s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.879 total time=   8.3s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.664 total time=   3.8s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.734 total time=   5.7s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.898 total time=   7.2s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.909 total time=   8.2s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.915 total time=   6.8s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.652 total time=   1.8s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.727 total time=   2.6s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.910 total time=   3.7s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.910 total time=   2.8s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.926 total time=   2.9s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.678 total time=   1.5s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.751 total time=   1.8s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.901 total time=   3.2s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.905 total time=   2.5s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.919 total time=   2.2s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
print(grid.best_estimator_)
# we are getting these as best parameters
# Out:
# SVC(C=1000, gamma=0.0001)

# %%
grid_predictions = grid.predict(scaled_test)

# %%
confusion_matrix(y_test,grid_predictions)
pd.crosstab(y_test, grid_predictions, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0    1   All
# True
# 0           933  108  1041
# 1           166  202   368
# All        1099  310  1409

# %% [markdown]
# <p style="color:DodgerBlue; ">  Even with best parameters after Grid Search, we are still getting very high mis-classification
#     rate but again churners are being classified nicely.
#     <br><br>
#     <b> One thing is clear that we need some sophisticated algorithm with low variance which can classify our data.</b>
# </p><br> <br><br></b>
#
# <h3> Model 5  : Random Forest </h3>

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(random_state = 9)
modelF = forest.fit(scaled_train, y_train_res)
pred = modelF.predict(scaled_test)

# %%
confusion_matrix(y_test,pred)
pd.crosstab(y_test, pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0    1   All
# True
# 0           906  135  1041
# 1           190  178   368
# All        1096  313  1409

# %%
forest2 = RandomForestClassifier(n_estimators=1000, oob_score = True, n_jobs = -1,random_state =9,
                                max_features = "auto", max_leaf_nodes = 7)

# %%
modelF2 = forest2.fit(scaled_train, y_train_res)
pred2 = modelF2.predict(scaled_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %%
confusion_matrix(y_test,pred2)
pd.crosstab(y_test, pred2, rownames=['True'], colnames=['Predicted'], margins=True)

# As we increased number of estimators and max_leaf_nodes, we are starting to get better results.
# Total mis-classified points is 517 which is best till now.
# Out:
# Predicted    0    1   All
# True
# 0          803  238  1041
# 1          113  255   368
# All        916  493  1409

# %%
forest3 = RandomForestClassifier(n_estimators=1200, oob_score = True, n_jobs = -1,random_state =9,
                                max_features = "auto", max_leaf_nodes = 10)

# %%
modelF3 = forest3.fit(scaled_train, y_train_res)
pred3 = modelF3.predict(scaled_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %%
confusion_matrix(y_test,pred3)
pd.crosstab(y_test, pred3, rownames=['True'], colnames=['Predicted'], margins=True)

# we are getting 338 miss-classified points
# Out:
# Predicted    0    1   All
# True
# 0          821  220  1041
# 1          118  250   368
# All        939  470  1409

# %%
forest4 = RandomForestClassifier(n_estimators=1000, oob_score = True, n_jobs = -1,random_state =9,
                                max_features = "log2", max_leaf_nodes = 7)

# %%
modelF4 = forest4.fit(scaled_train, y_train_res)
pred4 = modelF4.predict(scaled_test)

# %%
confusion_matrix(y_test,pred4)
pd.crosstab(y_test, pred4, rownames=['True'], colnames=['Predicted'], margins=True)

# we are getting 513 miss-classified points no. of churners are getting missed.
# Out:
# Predicted    0    1   All
# True
# 0          799  242  1041
# 1          111  257   368
# All        910  499  1409

# %%
forest5 = RandomForestClassifier(n_estimators=700, oob_score = True, n_jobs = -1,random_state = 9,
                                max_features = "auto", max_leaf_nodes = 7)

# %%
modelF5 = forest5.fit(scaled_train, y_train_res)
pred5 = modelF5.predict(scaled_test)
confusion_matrix(y_test,pred5)
pd.crosstab(y_test, pred5, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Predicted    0    1   All
# True
# 0          805  236  1041
# 1          114  254   368
# All        919  490  1409

# %% [markdown]
# <p style="color:DodgerBlue; ">  <b> There's a major problem that we are facing here. Number of features that we are
#      considering here are too many and even some non-important features are also contributing to the model.
#     Before moving forward, we'll be carrying feature importance and only keep top 30 predictors in our data.</b>
# </p><br> <br><br></b>
# <h3> Feature Importance Using Scikit-Learn </h3>

# %%
importances = modelF5.feature_importances_

# %%
std = np.std([tree.feature_importances_ for tree in modelF5.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# %%
features = X_train_res.columns

# %%
# Print the feature ranking
print("Feature ranking:")

for f in range(X_train_res.shape[1]):
    print("%d. feature %d (%f) and feature name : %s" % (f+1 , indices[f], importances[indices[f]], features[indices[f]]))
# Out:
# Feature ranking:
# 1. feature 37 (0.173125) and feature name : Contract_Month-to-month
# 2. feature 19 (0.128790) and feature name : OnlineSecurity_No
# 3. feature 28 (0.127034) and feature name : TechSupport_No
# 4. feature 44 (0.110553) and feature name : PaymentMethod_Electronic check
# 5. feature 0 (0.076585) and feature name : tenure
# 6. feature 22 (0.073158) and feature name : OnlineBackup_No
# 7. feature 17 (0.052455) and feature name : InternetService_Fiber optic
# 8. feature 25 (0.051956) and feature name : DeviceProtection_No
# 9. feature 2 (0.028854) and feature name : TotalCharges
# 10. feature 41 (0.026321) and feature name : PaperlessBilling_Yes
# 11. feature 39 (0.025442) and feature name : Contract_Two year
# 12. feature 7 (0.021919) and feature name : Partner_No
# 13. feature 9 (0.019120) and feature name : Dependents_No
# 14. feature 1 (0.007476) and feature name : MonthlyCharges
# 15. feature 32 (0.006490) and feature name : StreamingTV_No internet service
# 16. feature 6 (0.005890) and feature name : SeniorCitizen_1
# 17. feature 35 (0.004885) and feature name : StreamingMovies_No internet service
# 18. feature 29 (0.004395) and feature name : TechSupport_No internet service
# 19. feature 38 (0.004143) and feature name : Contract_One year
# 20. feature 23 (0.004036) and feature name : OnlineBackup_No internet service
# 21. feature 26 (0.003778) and feature name : DeviceProtection_No internet service
# 22. feature 20 (0.003740) and feature name : OnlineSecurity_No internet service
# 23. feature 34 (0.003643) and feature name : StreamingMovies_No
# 24. feature 30 (0.003489) and feature name : TechSupport_Yes
# 25. feature 24 (0.003347) and feature name : OnlineBackup_Yes
# 26. feature 21 (0.003272) and feature name : OnlineSecurity_Yes
# 27. feature 27 (0.003072) and feature name : DeviceProtection_Yes
# 28. feature 18 (0.002935) and feature name : InternetService_No
# 29. feature 16 (0.002434) and feature name : InternetService_DSL
# 30. feature 8 (0.002153) and feature name : Partner_Yes
# 31. feature 40 (0.001981) and feature name : PaperlessBilling_No
# 32. feature 31 (0.001942) and feature name : StreamingTV_No
# 33. feature 3 (0.001689) and feature name : gender_Female
# 34. feature 33 (0.001553) and feature name : StreamingTV_Yes
# 35. feature 36 (0.001521) and feature name : StreamingMovies_Yes
# 36. feature 4 (0.001487) and feature name : gender_Male
# 37. feature 15 (0.001395) and feature name : MultipleLines_Yes
# 38. feature 13 (0.000776) and feature name : MultipleLines_No
# 39. feature 14 (0.000593) and feature name : MultipleLines_No phone service
# 40. feature 10 (0.000541) and feature name : Dependents_Yes
# 41. feature 5 (0.000502) and feature name : SeniorCitizen_0
# 42. feature 45 (0.000466) and feature name : PaymentMethod_Mailed check
# 43. feature 42 (0.000412) and feature name : PaymentMethod_Bank transfer (automatic)
# 44. feature 11 (0.000405) and feature name : PhoneService_No
# 45. feature 43 (0.000220) and feature name : PaymentMethod_Credit card (automatic)
# 46. feature 12 (0.000029) and feature name : PhoneService_Yes

# %%
# Plot the impurity-based feature importances of the forest
plt.figure(figsize=(15,10))
plt.title("Feature importances")
plt.bar(range(X_train_res.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(X_train_res.shape[1]), indices)
plt.xlim([-1, X_train_res.shape[1]])
plt.show()

# %%
# Subsetting X_train_res
top_30 = indices[:30]

# %%
fe_train = X_train_res.iloc[:, top_30]
fe_train.shape
# Out:
# (8266, 30)

# %%
# Similarly for test data
fe_test = X_test.iloc[:, top_30]
fe_test.shape
# Out:
# (1409, 30)

# %%
# Scaling new data now
scaled_train_fe = StandardScaler().fit_transform(fe_train)
scaled_test_fe = StandardScaler().fit_transform(fe_test)

# %% [markdown]
# <h3> Back to Modeling </h3>

# %%
forest6 = RandomForestClassifier(n_estimators=500, oob_score = True, n_jobs = -1,random_state = 9,
                                max_features = "auto", max_leaf_nodes = 6)

modelF6 = forest6.fit(scaled_train_fe, y_train_res)
pred6 = modelF6.predict(scaled_test_fe)
confusion_matrix(y_test,pred6)
pd.crosstab(y_test, pred6, rownames=['True'], colnames=['Predicted'], margins=True)

# After this we are getting 360 mis-classified points
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Predicted    0    1   All
# True
# 0          792  249  1041
# 1          109  259   368
# All        901  508  1409

# %% [markdown]
# <h3> Model 5 : AdaBoost </h3>

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada_clf = AdaBoostClassifier(random_state=9)
ada_clf.fit(scaled_train, y_train_res)

pred = ada_clf.predict(scaled_test)
confusion_matrix(y_test,pred)
pd.crosstab(y_test, pred, rownames=['True'], colnames=['Predicted'], margins=True)

# With no hyper-parameter tuning base AdaBoostClassifier performing equal to our best model
# Out:
# Predicted     0    1   All
# True
# 0           873  168  1041
# 1           142  226   368
# All        1015  394  1409

# %%
ada_clf_1 = AdaBoostClassifier(n_estimators=200, learning_rate=0.5, random_state=9, algorithm='SAMME.R')
ada_clf_1.fit(scaled_train_fe, y_train_res)

pred1 = ada_clf_1.predict(scaled_test_fe)
confusion_matrix(y_test,pred1)
pd.crosstab(y_test, pred1, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted    0    1   All
# True
# 0          821  220  1041
# 1          113  255   368
# All        934  475  1409

# %% [markdown]
# <br><br><p style="color:DodgerBlue; "> Till this point, we have AdaBoostClassifier as best model with miss-classification of 351 points
#      in total.
# </p><br> <br></b>
#
#
# <h3> Model 6 : Gradient Boosting Classifier </h3>

# %%
from xgboost import XGBClassifier# fit model no training data

# %%
# Fitting Base model
xgb_model = XGBClassifier()
xgb_model.fit(scaled_train_fe, y_train_res)

pred1 = xgb_model.predict(scaled_test_fe)
confusion_matrix(y_test,pred1)
pd.crosstab(y_test, pred1, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0    1   All
# True
# 0           864  177  1041
# 1           136  232   368
# All        1000  409  1409

# %% [markdown]
# <br> <br>
# <h3> Let's see model's performance in tabular form </h3> <br> <br>
#
# <table style="width:80%;">
#   <tr>
#     <th> Serial Number </th>
#     <th> Model Name </th>
#     <th>Mis-Classified Points</th>
#       <th>Mis-Classified Churners</th>
#   </tr>
#
#
#   <tr>
#     <td>1.</td>
#     <td>Decision Trees</td>
#     <td>370</td>
#       <td>141</td>
#   </tr>
#   <tr>
#     <td>2.</td>
#     <td>K-Nearesr Neighbors</td>
#     <td>340</td>
#       <td>132</td>
#   </tr>
#
#   <tr>
#     <td>3.</td>
#     <td>Logistic Regression</td>
#     <td>363</td>
#       <td>91</td>
#   </tr>
#   <tr>
#     <td>4.</td>
#     <td>Support Vector Machine</td>
#     <td>378</td>
#       <td>167</td>
#   </tr>
#
#    <tr>
#     <td>5.</td>
#     <td>Random Forest</td>
#     <td>338</td>
#        <td>107</td>
#   </tr>
#   <tr>
#     <td>6.</td>
#     <td>AdaBoost</td>
#     <td>302</td>
#       <td>106</td>
#    </tr>
#    <tr>
#     <td>7.</td>
#     <td>XGBoost</td>
#     <td>337</td>
#        <td>145</td>
#    </tr>
#
# </table> <br> <br>
# <h4> <b> We have 3 Options which we can consider. <br><br>
#     1. Logistic regression model, which is overall slightly better performer in terms of predicting churners
#      but it's miss-classification rate is too high. <br> <br>
#     2. Random Forest Model whose miss-classification rate for predicting churners is 3rd lowest and also overall mis-classification rate is also low.<br><br>
#     3. Ada Boost Model whose miss-classification rate for predicting churners is 2nd lowest and also overall mis-classification rate is also lowest.<br><br><br>
#
#     We'd be moving ahead with our Ada Boost Model for production as it seems to be best fit.

# %%
import pickle
# Lets dump our Adaboost model
pickle.dump(ada_clf_1, open('adaboost.pkl','wb'))
